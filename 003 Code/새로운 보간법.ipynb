# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.05        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수


# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/00329601(0002)'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_10%'


def custom_interpolate_series(arr: np.ndarray) -> np.ndarray:
    """
    1D numpy array arr에 대해
      • WINDOW 범위 내 2+2 확보 → 코사인 유사도 기반 보간
        - S >  0.5 → 선형(custom)
        - S < -0.5 → 외삽(custom)
        - 그 외    → 혼합(custom)
      • 남은 NaN → pandas 선형 보간(fallback)

    출력 예시:
      → custom lin : 1716
      → custom ext :  212
      → custom mix :  120
      → fallback   : 39273
      (총 41479 NaNs)
    """
    y = arr.copy().astype(float)
    nan_idx = np.where(np.isnan(y))[0]

    WINDOW = 1000
    cnt_lin = cnt_ext = cnt_mix = cnt_fb = 0

    # 1) custom 보간
    for t in nan_idx:
        # 주변 WINDOW 안에서 2개씩 찾기
        left, right = [], []
        i = t-1
        while i >= max(0, t-WINDOW) and len(left)<2:
            if not np.isnan(y[i]): left.append(y[i])
            i -= 1
        i = t+1
        while i <= min(len(y)-1, t+WINDOW) and len(right)<2:
            if not np.isnan(y[i]): right.append(y[i])
            i += 1

        if len(left)==2 and len(right)==2:
            a, b = left[1], left[0]
            c, d = right[0], right[1]
            S = (a*c + b*d) / (np.hypot(a,b) * np.hypot(c,d))
            if S >  0.5:
                y[t] = (b + c) / 2
                cnt_lin += 1
            elif S < -0.5:
                y[t] = ((2*b - a) + (2*c - d)) / 2
                cnt_ext += 1
            else:
                lin   = (b + c) / 2
                ext   = ((2*b - a) + (2*c - d)) / 2
                y[t] = 0.5*lin + 0.5*ext
                cnt_mix += 1

    # 2) pandas 선형 fallback
    rem = np.isnan(y).sum()
    if rem>0:
        before = rem
        y = pd.Series(y).interpolate(method='linear').to_numpy()
        after  = np.isnan(y).sum()
        cnt_fb = before - after

    total = len(nan_idx)
    print(f" → custom lin : {cnt_lin}")
    print(f" → custom ext : {cnt_ext}")
    print(f" → custom mix : {cnt_mix}")
    print(f" → fallback   : {cnt_fb}")
    print(f" (총 {total} NaNs)")

    return y

def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)
        
        # 6. 커스텀 보간
        for col in cel_cols:
            clean_df[col] = custom_interpolate_series(clean_df[col].to_numpy())


        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
# Out:
#  → custom lin : 40066
#  → custom ext : 0
#  → custom mix : 0
#  → fallback   : 923
#  (총 41479 NaNs)
#  → custom lin : 40132
#  → custom ext : 0
#  → custom mix : 0
#  → fallback   : 926
#  (총 41548 NaNs)
#  → custom lin : 40088
#  → custom ext : 0
#  → custom mix : 0
#  → fallback   : 924
#  (총 41502 NaNs)
#  → custom lin : 40082
#  → custom ext : 0
#  → custom mix : 0
#  → fallback   : 924
#  (총 41496 NaNs)
#  → custom lin : 40098
#  → custom ext : 0
#  → custom mix : 0
#  → fallback   : 924
#  (총 41512 NaNs)
#  → custom lin : 40077
#  → custom ext : 0
#  → custom mix : 0
#  → fallback   : 924
#  (총 41491 NaNs)
#  → custom lin : 40077
#  → custom ext : 0
#  → custom mix : 0
#  → fallback   : 926
#  (총 41493 NaNs)
#  → custom lin : 40170
#  → custom ext : 0
#  → custom mix : 0
#  → fallback   : 924
#  (총 41585 NaNs)
#  → custom lin : 40166
#  → custom ext : 0
#  → custom mix : 0
#  → fallback   : 926
#  (총 41582 NaNs)
#  → custom lin : 40055
#  → custom ext : 0
#  → custom mix : 0
#  → fallback   : 924
#  (총 41469 NaNs)
#  → custom lin : 40096
#  → custom ext : 0
#  → custom mix : 0
#  → fallback   : 924
#  (총 41510 NaNs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 226
#     223 np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)
#     225 os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
# --> 226 preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
#
# Cell In[9], line 187, in preprocess_ess_folder(ess_dir, root_out_dir)
#     185 # 6. 커스텀 보간
#     186 for col in cel_cols:
# --> 187     clean_df[col] = custom_interpolate_series(clean_df[col].to_numpy())
#     190 # 7. 전압 기준 유효 날짜 필터
#     191 valid_counts = (
#     192     clean_df.groupby('date')[cel_cols]
#     193     .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
#     194 )
#
# Cell In[9], line 70, in custom_interpolate_series(arr)
#      68     i -= 1
#      69 i = t+1
# ---> 70 while i <= min(len(y)-1, t+WINDOW) and len(right)<2:
#      71     if not np.isnan(y[i]): right.append(y[i])
#      72     i += 1
#
# KeyboardInterrupt:

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.05        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/3.A.R5M7C11'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_5%'

def baseline_profile_impute(df: pd.DataFrame,
                            cel_cols: List[str],
                            P: np.ndarray) -> pd.DataFrame:
    """
    df: colec_dt 기준 정렬된 하루치 DataFrame (1440×C)
    cel_cols: ['cell_volt_1', …] 전압 컬럼 리스트
    P: (1440×C) 기준 패턴 배열
    """
    n = len(df)
    any_nan = df[cel_cols].isna().any(axis=1)
    nan_idx = np.where(any_nan)[0]
    if len(nan_idx)==0:
        return df

    gaps = np.split(nan_idx, np.where(np.diff(nan_idx)!=1)[0]+1)
    for gap in gaps:
        a, b = gap[0]-1, gap[-1]+1
        # 경계 처리
        if a<0:  a = gap[-1]+1; d_a = 0
        else:    d_a = df.iloc[a][cel_cols].to_numpy() - P[a]
        if b>=n: b = gap[0]-1; d_b = 0
        else:    d_b = df.iloc[b][cel_cols].to_numpy() - P[b]

        L = len(gap)
        for i, t in enumerate(gap, start=1):
            u = i/(L+1)
            d_interp = (1-u)*d_a + u*d_b
            df.iloc[t, df.columns.get_indexer(cel_cols)] = P[t] + d_interp

    return df



def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # 6. 기준 패턴 기반 보간법 적용
        # (a) 이 폴더 내 정상 날짜 전체로부터 하루 평균 패턴 P 계산
        dates = clean_df['date'].unique()
        arr = np.stack([
            clean_df.loc[clean_df['date']==d, cel_cols].to_numpy()
            for d in dates
        ], axis=0)            # (NDays, 1440, C)
        P = arr.mean(axis=0)  # (1440, C)

        # (b) 날짜별로 baseline_profile_impute 호출
        imputed = []
        for d in dates:
            sub = clean_df[clean_df['date']==d].reset_index(drop=True)  # 1440×C
            sub_imp = baseline_profile_impute(sub, cel_cols, P)       # 1440×C 보간
            sub_imp['date'] = d
            imputed.append(sub_imp)
        clean_df = pd.concat(imputed, ignore_index=True)


        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
# Out:
# [WARN] preprocessing_A/3.A.R5M7C11/rack4_module1.csv : no valid dates left
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 203
#     200 np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)
#     202 os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
# --> 203 preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
#
# Cell In[2], line 161, in preprocess_ess_folder(ess_dir, root_out_dir)
#     159 for d in dates:
#     160     sub = clean_df[clean_df['date']==d].reset_index(drop=True)  # 1440×C
# --> 161     sub_imp = baseline_profile_impute(sub, cel_cols, P)       # 1440×C 보간
#     162     sub_imp['date'] = d
#     163     imputed.append(sub_imp)
#
# Cell In[2], line 64, in baseline_profile_impute(df, cel_cols, P)
#      62         u = i/(L+1)
#      63         d_interp = (1-u)*d_a + u*d_b
# ---> 64         df.iloc[t, df.columns.get_indexer(cel_cols)] = P[t] + d_interp
#      66 return df
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexing.py:1942, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
# -> 1942     self._setitem_with_indexer_split_path(indexer, value, name)
#    1943 else:
#    1944     self._setitem_single_block(indexer, value, name)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexing.py:2016, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    2013 elif len(ilocs) == len(value):
#    2014     # We are setting multiple columns in a single row.
#    2015     for loc, v in zip(ilocs, value):
# -> 2016         self._setitem_single_column(loc, v, pi)
#    2018 elif len(ilocs) == 1 and com.is_null_slice(pi) and len(self.obj) == 0:
#    2019     # This is a setitem-with-expansion, see
#    2020     #  test_loc_setitem_empty_append_expands_rows_mixed_dtype
#    2021     # e.g. df = DataFrame(columns=["x", "y"])
#    2022     #  df["x"] = df["x"].astype(np.int64)
#    2023     #  df.loc[:, "x"] = [1, 2, 3]
#    2024     self._setitem_single_column(ilocs[0], value, pi)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexing.py:2164, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2160         self.obj.isetitem(loc, value)
#    2161 else:
#    2162     # set value into the column (first attempting to operate inplace, then
#    2163     #  falling back to casting if necessary)
# -> 2164     dtype = self.obj.dtypes.iloc[loc]
#    2165     if dtype == np.void:
#    2166         # This means we're expanding, with multiple columns, e.g.
#    2167         #     df = pd.DataFrame({'A': [1,2,3], 'B': [4,5,6]})
#    (...)
#    2170         # Here, we replace those temporary `np.void` columns with
#    2171         # columns of the appropriate dtype, based on `value`.
#    2172         self.obj.iloc[:, loc] = construct_1d_array_from_inferred_fill_value(
#    2173             value, len(self.obj)
#    2174         )
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/generic.py:6461, in NDFrame.dtypes(self)
#    6434 """
#    6435 Return the dtypes in the DataFrame.
#    6436
#    (...)
#    6458 dtype: object
#    6459 """
#    6460 data = self._mgr.get_dtypes()
# -> 6461 return self._constructor_sliced(data, index=self._info_axis, dtype=np.object_)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/series.py:588, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     586 manager = _get_option("mode.data_manager", silent=True)
#     587 if manager == "block":
# --> 588     data = SingleBlockManager.from_array(data, index, refs=refs)
#     589 elif manager == "array":
#     590     data = SingleArrayManager.from_array(data, index)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/internals/managers.py:1872, in SingleBlockManager.from_array(cls, array, index, refs)
#    1870 array = maybe_coerce_values(array)
#    1871 bp = BlockPlacement(slice(0, len(index)))
# -> 1872 block = new_block(array, placement=bp, ndim=1, refs=refs)
#    1873 return cls(block, index)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/internals/blocks.py:2728, in new_block(values, placement, ndim, refs)
#    2716 def new_block(
#    2717     values,
#    2718     placement: BlockPlacement,
#    (...)
#    2725     # - check_ndim/ensure_block_shape already checked
#    2726     # - maybe_coerce_values already called/unnecessary
#    2727     klass = get_block_type(values.dtype)
# -> 2728     return klass(values, ndim=ndim, placement=placement, refs=refs)
#
# KeyboardInterrupt:

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.5        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/1.A.M5C10'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_5%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order=3)

        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
# Out:
# [OK] preprocessing_A/1.A.M5C10/rack8_module17.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module14.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module1.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module13.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module4.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module9.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module15.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module11.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module12.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module5.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module7.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module10.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module6.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module2.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module8.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module16.csv → A_5%/1.A.M5C10
# [OK] preprocessing_A/1.A.M5C10/rack8_module3.csv → A_5%/1.A.M5C10

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.05        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/00321804(0002)'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_5%'

def baseline_profile_impute(df: pd.DataFrame,
                            cel_cols: List[str],
                            P: np.ndarray) -> pd.DataFrame:
    """
    df: colec_dt 기준 정렬된 하루치 DataFrame (1440×C)
    cel_cols: ['cell_volt_1', …] 전압 컬럼 리스트
    P: (1440×C) 기준 패턴 배열
    """
    n = len(df)
    any_nan = df[cel_cols].isna().any(axis=1)
    nan_idx = np.where(any_nan)[0]
    if len(nan_idx)==0:
        return df

    gaps = np.split(nan_idx, np.where(np.diff(nan_idx)!=1)[0]+1)
    for gap in gaps:
        a, b = gap[0]-1, gap[-1]+1
        # 경계 처리
        if a<0:  a = gap[-1]+1; d_a = 0
        else:    d_a = df.iloc[a][cel_cols].to_numpy() - P[a]
        if b>=n: b = gap[0]-1; d_b = 0
        else:    d_b = df.iloc[b][cel_cols].to_numpy() - P[b]

        L = len(gap)
        for i, t in enumerate(gap, start=1):
            u = i/(L+1)
            d_interp = (1-u)*d_a + u*d_b
            df.iloc[t, df.columns.get_indexer(cel_cols)] = P[t] + d_interp

    return df



def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # 6. 기준 패턴 기반 보간법 적용
        # (a) 이 폴더 내 정상 날짜 전체로부터 하루 평균 패턴 P 계산
        dates = clean_df['date'].unique()
        arr = np.stack([
            clean_df.loc[clean_df['date']==d, cel_cols].to_numpy()
            for d in dates
        ], axis=0)            # (NDays, 1440, C)
        P = arr.mean(axis=0)  # (1440, C)

        # (b) 날짜별로 baseline_profile_impute 호출
        imputed = []
        for d in dates:
            sub = clean_df[clean_df['date']==d].reset_index(drop=True)  # 1440×C
            sub_imp = baseline_profile_impute(sub, cel_cols, P)       # 1440×C 보간
            sub_imp['date'] = d
            imputed.append(sub_imp)
        clean_df = pd.concat(imputed, ignore_index=True)


        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
# Out:
# [WARN] preprocessing_A/00321804(0002)/rack4_module1.csv : no valid dates left
# [WARN] preprocessing_A/00321804(0002)/rack16_module5.csv : no valid dates left
# [WARN] preprocessing_A/00321804(0002)/rack9_module9.csv : no valid dates left
# [WARN] preprocessing_A/00321804(0002)/rack17_module10.csv : no valid dates left
# [WARN] preprocessing_A/00321804(0002)/rack15_module9.csv : no valid dates left
# [WARN] preprocessing_A/00321804(0002)/rack6_module8.csv : no valid dates left
# [WARN] preprocessing_A/00321804(0002)/rack4_module2.csv : no valid dates left
# [WARN] preprocessing_A/00321804(0002)/rack9_module1.csv : no valid dates left
# [WARN] preprocessing_A/00321804(0002)/rack15_module17.csv : no valid dates left
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 203
#     200 np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)
#     202 os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
# --> 203 preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
#
# Cell In[3], line 161, in preprocess_ess_folder(ess_dir, root_out_dir)
#     159 for d in dates:
#     160     sub = clean_df[clean_df['date']==d].reset_index(drop=True)  # 1440×C
# --> 161     sub_imp = baseline_profile_impute(sub, cel_cols, P)       # 1440×C 보간
#     162     sub_imp['date'] = d
#     163     imputed.append(sub_imp)
#
# Cell In[3], line 64, in baseline_profile_impute(df, cel_cols, P)
#      62         u = i/(L+1)
#      63         d_interp = (1-u)*d_a + u*d_b
# ---> 64         df.iloc[t, df.columns.get_indexer(cel_cols)] = P[t] + d_interp
#      66 return df
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexing.py:1942, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
# -> 1942     self._setitem_with_indexer_split_path(indexer, value, name)
#    1943 else:
#    1944     self._setitem_single_block(indexer, value, name)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexing.py:2016, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    2013 elif len(ilocs) == len(value):
#    2014     # We are setting multiple columns in a single row.
#    2015     for loc, v in zip(ilocs, value):
# -> 2016         self._setitem_single_column(loc, v, pi)
#    2018 elif len(ilocs) == 1 and com.is_null_slice(pi) and len(self.obj) == 0:
#    2019     # This is a setitem-with-expansion, see
#    2020     #  test_loc_setitem_empty_append_expands_rows_mixed_dtype
#    2021     # e.g. df = DataFrame(columns=["x", "y"])
#    2022     #  df["x"] = df["x"].astype(np.int64)
#    2023     #  df.loc[:, "x"] = [1, 2, 3]
#    2024     self._setitem_single_column(ilocs[0], value, pi)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexing.py:2175, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2165     if dtype == np.void:
#    2166         # This means we're expanding, with multiple columns, e.g.
#    2167         #     df = pd.DataFrame({'A': [1,2,3], 'B': [4,5,6]})
#    (...)
#    2170         # Here, we replace those temporary `np.void` columns with
#    2171         # columns of the appropriate dtype, based on `value`.
#    2172         self.obj.iloc[:, loc] = construct_1d_array_from_inferred_fill_value(
#    2173             value, len(self.obj)
#    2174         )
# -> 2175     self.obj._mgr.column_setitem(loc, plane_indexer, value)
#    2177 self.obj._clear_item_cache()
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/internals/managers.py:1333, in BlockManager.column_setitem(self, loc, idx, value, inplace_only)
#    1329     self._iset_split_block(blkno, [blk_loc], values)
#    1331 # this manager is only created temporarily to mutate the values in place
#    1332 # so don't track references, otherwise the `setitem` would perform CoW again
# -> 1333 col_mgr = self.iget(loc, track_ref=False)
#    1334 if inplace_only:
#    1335     col_mgr.setitem_inplace(idx, value)
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/internals/managers.py:1017, in BlockManager.iget(self, i, track_ref)
#    1013 """
#    1014 Return the data as a SingleBlockManager.
#    1015 """
#    1016 block = self.blocks[self.blknos[i]]
# -> 1017 values = block.iget(self.blklocs[i])
#    1019 # shortcut for select a single-dim from a 2-dim BM
#    1020 bp = BlockPlacement(slice(0, len(values)))
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/internals/blocks.py:1253, in Block.iget(self, i)
#    1249 @property
#    1250 def shape(self) -> Shape:
#    1251     return self.values.shape
# -> 1253 def iget(self, i: int | tuple[int, int] | tuple[slice, int]) -> np.ndarray:
#    1254     # In the case where we have a tuple[slice, int], the slice will always
#    1255     #  be slice(None)
#    1256     # Note: only reached with self.ndim == 2
#    1257     # Invalid index type "Union[int, Tuple[int, int], Tuple[slice, int]]"
#    1258     # for "Union[ndarray[Any, Any], ExtensionArray]"; expected type
#    1259     # "Union[int, integer[Any]]"
#    1260     return self.values[i]  # type: ignore[index]
#    1262 def _slice(
#    1263     self, slicer: slice | npt.NDArray[np.bool_] | npt.NDArray[np.intp]
#    1264 ) -> ArrayLike:
#
# KeyboardInterrupt:

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.15        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

imputer = KNNImputer(n_neighbors=5,
                    weights='uniform',
                    metric='nan_euclidean')

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/00329601(0002)'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_5%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order=3)

        # 날짜별로 그룹 나누어 fit_transform
        for day, idx in clean_df.groupby('date').groups.items():
            sub = clean_df.loc[idx, cel_cols]               # 해당 날짜(그룹)의 1,440행
            imputed = imputer.fit_transform(sub)            # 하루치만 거리 계산
            clean_df.loc[idx, cel_cols] = pd.DataFrame(      # 원위치에 덮어쓰기
                imputed,
                columns=cel_cols,
                index=idx
            )

        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
# Out:
# [OK] preprocessing_A/00329601(0002)/rack4_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module13.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack2_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack11_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module2.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module17.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module10.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module6.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack3_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack6_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack8_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module16.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack14_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack15_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module3.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack9_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module9.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module4.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module14.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack4_module11.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack1_module7.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack5_module15.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack12_module8.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module5.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack10_module12.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack13_module1.csv → A_5%/00329601(0002)
# [OK] preprocessing_A/00329601(0002)/rack7_module17.csv → A_5%/00329601(0002)

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.15        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

imputer = KNNImputer(n_neighbors=5,
                    weights='uniform',
                    metric='nan_euclidean')

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/00391262(0002)'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_5%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order=3)

        # 날짜별로 그룹 나누어 fit_transform
        for day, idx in clean_df.groupby('date').groups.items():
            sub = clean_df.loc[idx, cel_cols]               # 해당 날짜(그룹)의 1,440행
            imputed = imputer.fit_transform(sub)            # 하루치만 거리 계산
            clean_df.loc[idx, cel_cols] = pd.DataFrame(      # 원위치에 덮어쓰기
                imputed,
                columns=cel_cols,
                index=idx
            )

        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
# Out:
# [OK] preprocessing_A/00391262(0002)/rack24_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack16_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack2_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack11_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack29_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module17.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack24_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack31_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module13.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack3_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack6_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack8_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module6.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack30_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack28_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack14_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack25_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack18_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack15_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack20_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module3.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack9_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack22_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack26_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack17_module16.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module9.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module4.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack21_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module14.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack4_module11.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack1_module7.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack23_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack19_module2.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack5_module15.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack12_module8.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module5.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack10_module12.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack13_module1.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack27_module10.csv → A_5%/00391262(0002)
# [OK] preprocessing_A/00391262(0002)/rack7_module17.csv → A_5%/00391262(0002)

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.15        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

imputer = KNNImputer(n_neighbors=5,
                    weights='uniform',
                    metric='nan_euclidean')

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/00451902(0002)'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_5%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order=3)

        # 날짜별로 그룹 나누어 fit_transform
        for day, idx in clean_df.groupby('date').groups.items():
            sub = clean_df.loc[idx, cel_cols]               # 해당 날짜(그룹)의 1,440행
            imputed = imputer.fit_transform(sub)            # 하루치만 거리 계산
            clean_df.loc[idx, cel_cols] = pd.DataFrame(      # 원위치에 덮어쓰기
                imputed,
                columns=cel_cols,
                index=idx
            )

        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
# Out:
# [OK] preprocessing_A/00451902(0002)/rack4_module1.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack16_module5.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module8.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack4_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module1.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack13_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack10_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack10_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack16_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack10_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module15.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack13_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack16_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack8_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module14.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack8_module14.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module5.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module14.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack5_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module14.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack4_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module1.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack10_module15.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module12.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module15.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module11.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module5.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module7.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack1_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack7_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack5_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack4_module15.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack8_module1.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack5_module7.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack8_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack13_module7.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module12.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module1.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack8_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module14.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack1_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack16_module7.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module16.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack16_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack13_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module7.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module5.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module15.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack16_module1.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack7_module3.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack14_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack14_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module8.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module16.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack8_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack16_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack16_module16.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack8_module15.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack13_module16.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module15.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module12.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack16_module15.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module7.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack4_module7.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack1_module3.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module1.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module8.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack10_module7.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack4_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module5.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack8_module11.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack10_module14.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack4_module12.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack1_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack8_module12.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack5_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack14_module5.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack10_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack4_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack1_module8.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack1_module15.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module3.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module11.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack4_module16.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module14.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module16.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack14_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack13_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module5.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module11.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack1_module5.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module14.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack7_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack4_module3.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack1_module14.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack7_module1.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack4_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack16_module3.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack1_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module12.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module3.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module11.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack5_module11.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack5_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack5_module12.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack7_module11.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module5.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module3.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack7_module10.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack7_module8.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack7_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack14_module12.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack8_module5.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module9.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module3.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack10_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack13_module15.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack8_module7.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack10_module8.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack9_module12.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module8.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack12_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack13_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module16.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module12.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack5_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack15_module5.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module3.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack3_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack7_module16.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack7_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack10_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack2_module7.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack1_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack6_module4.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack16_module17.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack13_module2.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module14.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack14_module6.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack11_module7.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack1_module13.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack10_module3.csv → A_5%/00451902(0002)
# [OK] preprocessing_A/00451902(0002)/rack14_module3.csv → A_5%/00451902(0002)

# %% [markdown]
# # 여기부터 실행하기

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.15        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

imputer = KNNImputer(n_neighbors=5,
                    weights='uniform',
                    metric='nan_euclidean')

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/00465382(0002)'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_5%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order=3)

        # 날짜별로 그룹 나누어 fit_transform
        for day, idx in clean_df.groupby('date').groups.items():
            sub = clean_df.loc[idx, cel_cols]               # 해당 날짜(그룹)의 1,440행
            imputed = imputer.fit_transform(sub)            # 하루치만 거리 계산
            clean_df.loc[idx, cel_cols] = pd.DataFrame(      # 원위치에 덮어쓰기
                imputed,
                columns=cel_cols,
                index=idx
            )

        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
# Out:
# [OK] preprocessing_A/00465382(0002)/rack4_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module13.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack16_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack2_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack11_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module2.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module17.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module10.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module6.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack3_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack6_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack8_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module16.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack14_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack15_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module3.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack9_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module9.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module4.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module14.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack4_module11.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack1_module7.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack5_module15.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack12_module8.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module5.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack10_module12.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack13_module1.csv → A_5%/00465382(0002)
# [OK] preprocessing_A/00465382(0002)/rack7_module17.csv → A_5%/00465382(0002)

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.15        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

imputer = KNNImputer(n_neighbors=5,
                    weights='uniform',
                    metric='nan_euclidean')

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/00466746(0002)'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_5%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order=3)

        # 날짜별로 그룹 나누어 fit_transform
        for day, idx in clean_df.groupby('date').groups.items():
            sub = clean_df.loc[idx, cel_cols]               # 해당 날짜(그룹)의 1,440행
            imputed = imputer.fit_transform(sub)            # 하루치만 거리 계산
            clean_df.loc[idx, cel_cols] = pd.DataFrame(      # 원위치에 덮어쓰기
                imputed,
                columns=cel_cols,
                index=idx
            )

        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
# Out:
# [OK] preprocessing_A/00466746(0002)/rack4_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module13.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack16_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack2_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack11_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module2.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module17.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module10.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module6.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack3_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack6_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack8_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack14_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack18_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack15_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module3.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack9_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack17_module16.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module9.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module4.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module14.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack4_module11.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack1_module7.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack5_module15.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack12_module8.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module5.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack10_module12.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack13_module1.csv → A_5%/00466746(0002)
# [OK] preprocessing_A/00466746(0002)/rack7_module17.csv → A_5%/00466746(0002)

# %% [markdown]
# # 00454547, 00370960

# %%
import os
import glob
import numpy as np
import pandas as pd

# ────────────────────────────────────────────────────────────────
# 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED = 42                # 고정 시드
MISSING_RATE = 0.15      # 결측치 비율 (5%)
ROOT_OUTPUT_DIR = 'A_5%'  # 최상위 저장 폴더


def process_bank_data_2d(df, bank_label, base_filename, output_folder):
    """
    bank_no별 데이터를 받아서 베이스 코드 전처리를 적용한 후,
    채널별 2D (날짜수×1440) 배열로 저장합니다.
    """
    df_copy = df.copy()
    # 1. 시간 컬럼 처리
    if "colec_dt" not in df_copy.columns:
        if "clct_dt" in df_copy.columns:
            df_copy.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
        else:
            print(f"{base_filename} - bank {bank_label}: 시간 컬럼 없음, 스킵")
            return

    # 2. 전압 컬럼 이름 정규화
    if not any(col.startswith("cell_volt_") for col in df_copy.columns):
        rename_dict = {}
        for col in df_copy.columns:
            if col.startswith("cel_volt_"):
                num = col.replace("cel_volt_", "")
                if num.isdigit():
                    rename_dict[col] = f"cell_volt_{int(num)}"
        if rename_dict:
            df_copy.rename(columns=rename_dict, inplace=True)

    # 3. datetime 변환 및 재인덱싱
    df_copy["colec_dt"] = pd.to_datetime(df_copy["colec_dt"])
    start, end = df_copy["colec_dt"].min(), df_copy["colec_dt"].max()
    full_idx = pd.DataFrame({"colec_dt": pd.date_range(start, end, freq='min')})
    merged = pd.merge(full_idx, df_copy, on="colec_dt", how="left")
    merged = merged.groupby("colec_dt").first().reset_index()

    # 4. 불필요 컬럼 제거
    if "Unnamed: 0" in merged.columns:
        merged.drop(columns=["Unnamed: 0"], inplace=True)

    # 5. 전압 NaN 처리 및 필터링
    volt_cols = [c for c in merged.columns if c.startswith("cell_volt_")]
    merged.loc[merged[volt_cols[0]] < 3.3, volt_cols] = np.nan
    merged["date"] = merged["colec_dt"].dt.date
    nan_thr = 1400
    bad = merged.groupby("date")[volt_cols[0]].apply(lambda x: x.isna().sum())
    ok_days = bad[bad <= nan_thr].index
    merged = merged[merged["date"].isin(ok_days)].reset_index(drop=True)

    # 6. ★ 결측치 5% 무작위 주입 ★
    rng = np.random.default_rng(SEED)
    mask = rng.random(merged[volt_cols].shape) < MISSING_RATE
    merged.loc[:, volt_cols] = merged[volt_cols].mask(mask)

    # # 7. 선형 보간
    # merged[volt_cols] = merged[volt_cols].interpolate(method="polynomial", order=3)
    
    # 7. KNN 보간
    imputer = KNNImputer(n_neighbors=5,
                        weights='uniform',
                        metric='nan_euclidean')
    for day, idx in merged.groupby('date').groups.items():
        sub = merged.loc[idx, volt_cols]              # 해당 날짜(1,440행)만 추출
        imputed = imputer.fit_transform(sub)          # 하루치만 이웃 탐색
        merged.loc[idx, volt_cols] = pd.DataFrame(    # 보간 결과를 원위치에 덮어쓰기
            imputed,
            columns=volt_cols,
            index=idx
        )


    # 8. 유효일 필터링
    vt_thr, req_count = 3.6, 400*len(volt_cols)
    vc = merged.groupby("date")[volt_cols].apply(lambda df: (df>=vt_thr).sum().sum())
    keep = vc[vc>=req_count].index
    merged = merged[merged["date"].isin(keep)].reset_index(drop=True)

    # 9. 가장 앞/뒤 하루 제거
    dates = merged["date"].unique()
    if len(dates) <= 2:
        print(f"{base_filename} - bank {bank_label}: 유효일 부족")
        return
    merged = merged[~merged["date"].isin([dates[0], dates[-1]])].reset_index(drop=True)
    unique_dates = merged["date"].unique()

    # 10. 채널별 2D 배열 생성 및 저장 (float32)
    for volt in volt_cols:
        X = np.empty([len(unique_dates), 1440], dtype=np.float32)
        valid_idx = []
        for i, d in enumerate(unique_dates):
            day = merged[merged["date"]==d]
            series = day[volt]
            if series.shape[0] != 1440:
                print(f"{base_filename}, bank{bank_label}, {d}, {volt}: {series.shape[0]} rows")
                continue
            valid_idx.append(i)
            X[i] = series.to_numpy(dtype=np.float32)
        if not valid_idx:
            print(f"{base_filename} - bank {bank_label}: {volt} 유효 데이터 없음")
            continue
        X = X[valid_idx]
        out_path = os.path.join(output_folder, f"{base_filename}_{volt}.npy")
        np.save(out_path, X)
        print(f"Saved: {out_path} shape={X.shape}")

# ────────────────────────────────────────────────────────────────
# 사용 예시
# ────────────────────────────────────────────────────────────────
if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 고정

    input_folder = 'preprocessing_A/00454547(0002)'
    ess_files = glob.glob(os.path.join(input_folder, '*.csv'))
    base = os.path.basename(input_folder)

    # ★ A_5%/<base>_1, A_5%/<base>_2 폴더 생성 ★
    bank1_out = os.path.join(ROOT_OUTPUT_DIR, f"{base}_1")
    bank2_out = os.path.join(ROOT_OUTPUT_DIR, f"{base}_2")
    for p in [bank1_out, bank2_out]:
        os.makedirs(p, exist_ok=True)

    for path in ess_files:
        df = pd.read_csv(path)
        name = os.path.splitext(os.path.basename(path))[0]
        df1 = df[df['bsc_fg_no']==1]
        df2 = df[df['bsc_fg_no']==2]
        if not df1.empty:
            process_bank_data_2d(df1, 1, name, bank1_out)
        if not df2.empty:
            process_bank_data_2d(df2, 2, name, bank2_out)
# Out:
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module1_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_1.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_2.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_3.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_4.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_5.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_6.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_7.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_8.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_9.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_10.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_11.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_12.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_13.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module1_cell_volt_14.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module5_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module5_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module9_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_1.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_2.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_3.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_4.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_5.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_6.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_7.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_8.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_9.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_10.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_11.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_12.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_13.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module9_cell_volt_14.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack17_module10_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module9_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_1.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_2.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_3.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_4.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_5.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_6.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_7.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_8.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_9.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_10.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_11.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_12.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_13.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module9_cell_volt_14.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module8_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_1.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_2.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_3.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_4.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_5.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_6.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_7.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_8.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_9.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_10.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_11.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_12.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_13.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module8_cell_volt_14.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack4_module2_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack4_module2_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module1_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_1.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_2.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_3.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_4.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_5.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_6.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_7.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_8.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_9.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_10.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_11.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_12.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_13.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module1_cell_volt_14.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack15_module17_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack15_module17_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_1.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_2.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_3.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_4.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_5.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_6.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_7.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_8.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_9.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_10.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_11.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_12.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_13.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module13_cell_volt_14.npy shape=(37, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module13_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module2_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module2_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack9_module17_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_1.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_2.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_3.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_4.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_5.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_6.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_7.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_8.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_9.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_10.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_11.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_12.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_13.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack9_module17_cell_volt_14.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module9_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module9_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack2_module17_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_1.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_2.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_3.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_4.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_5.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_6.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_7.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_8.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_9.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_10.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_11.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_12.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_13.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack2_module17_cell_volt_14.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module2_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module2_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module9_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_1.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_2.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_3.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_4.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_5.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_6.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_7.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_8.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_9.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_10.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_11.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_12.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_13.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module9_cell_volt_14.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module10_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_1.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_2.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_3.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_4.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_5.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_6.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_7.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_8.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_9.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_10.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_11.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_12.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_13.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module10_cell_volt_14.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module15_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module15_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module9_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module9_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack11_module4_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_1.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_2.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_3.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_4.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_5.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_6.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_7.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_8.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_9.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_10.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_11.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_12.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_13.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack11_module4_cell_volt_14.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack6_module10_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack6_module10_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack16_module4_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack16_module4_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack8_module17_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack8_module17_cell_volt_1.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack8_module17_cell_volt_2.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack8_module17_cell_volt_3.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack8_module17_cell_volt_4.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack8_module17_cell_volt_5.npy shape=(35, 1440)
# ...
# Saved: A_5%/00454547(0002)_2/rack1_module7_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack1_module7_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack1_module7_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack1_module7_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack1_module7_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack1_module7_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack1_module7_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack1_module7_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack1_module7_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack1_module7_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module8_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module8_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack5_module15_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack5_module15_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack12_module8_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack12_module8_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module5_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module5_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack10_module12_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_1.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_2.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_3.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_4.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_5.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_6.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_7.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_8.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_9.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_10.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_11.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_12.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_13.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_2/rack10_module12_cell_volt_14.npy shape=(35, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack13_module1_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack13_module1_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_1/rack7_module17_cell_volt_14.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_1.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_2.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_3.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_4.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_5.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_6.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_7.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_8.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_9.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_10.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_11.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_12.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_13.npy shape=(36, 1440)
# Saved: A_5%/00454547(0002)_2/rack7_module17_cell_volt_14.npy shape=(36, 1440)

# %%
import os
import glob
import numpy as np
import pandas as pd

# ────────────────────────────────────────────────────────────────
# 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED = 42                # 고정 시드
MISSING_RATE = 0.15      # 결측치 비율 (5%)
ROOT_OUTPUT_DIR = 'A_5%'  # 최상위 저장 폴더


def process_bank_data_2d(df, bank_label, base_filename, output_folder):
    """
    bank_no별 데이터를 받아서 베이스 코드 전처리를 적용한 후,
    채널별 2D (날짜수×1440) 배열로 저장합니다.
    """
    df_copy = df.copy()
    # 1. 시간 컬럼 처리
    if "colec_dt" not in df_copy.columns:
        if "clct_dt" in df_copy.columns:
            df_copy.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
        else:
            print(f"{base_filename} - bank {bank_label}: 시간 컬럼 없음, 스킵")
            return

    # 2. 전압 컬럼 이름 정규화
    if not any(col.startswith("cell_volt_") for col in df_copy.columns):
        rename_dict = {}
        for col in df_copy.columns:
            if col.startswith("cel_volt_"):
                num = col.replace("cel_volt_", "")
                if num.isdigit():
                    rename_dict[col] = f"cell_volt_{int(num)}"
        if rename_dict:
            df_copy.rename(columns=rename_dict, inplace=True)

    # 3. datetime 변환 및 재인덱싱
    df_copy["colec_dt"] = pd.to_datetime(df_copy["colec_dt"])
    start, end = df_copy["colec_dt"].min(), df_copy["colec_dt"].max()
    full_idx = pd.DataFrame({"colec_dt": pd.date_range(start, end, freq='min')})
    merged = pd.merge(full_idx, df_copy, on="colec_dt", how="left")
    merged = merged.groupby("colec_dt").first().reset_index()

    # 4. 불필요 컬럼 제거
    if "Unnamed: 0" in merged.columns:
        merged.drop(columns=["Unnamed: 0"], inplace=True)

    # 5. 전압 NaN 처리 및 필터링
    volt_cols = [c for c in merged.columns if c.startswith("cell_volt_")]
    merged.loc[merged[volt_cols[0]] < 3.3, volt_cols] = np.nan
    merged["date"] = merged["colec_dt"].dt.date
    nan_thr = 1400
    bad = merged.groupby("date")[volt_cols[0]].apply(lambda x: x.isna().sum())
    ok_days = bad[bad <= nan_thr].index
    merged = merged[merged["date"].isin(ok_days)].reset_index(drop=True)

    # 6. ★ 결측치 5% 무작위 주입 ★
    rng = np.random.default_rng(SEED)
    mask = rng.random(merged[volt_cols].shape) < MISSING_RATE
    merged.loc[:, volt_cols] = merged[volt_cols].mask(mask)

    # # 7. 선형 보간
    # merged[volt_cols] = merged[volt_cols].interpolate(method="polynomial", order=3)

    # 7. KNN 보간
    imputer = KNNImputer(n_neighbors=5,
                        weights='uniform',
                        metric='nan_euclidean')
    for day, idx in merged.groupby('date').groups.items():
        sub = merged.loc[idx, volt_cols]              # 해당 날짜(1,440행)만 추출
        imputed = imputer.fit_transform(sub)          # 하루치만 이웃 탐색
        merged.loc[idx, volt_cols] = pd.DataFrame(    # 보간 결과를 원위치에 덮어쓰기
            imputed,
            columns=volt_cols,
            index=idx
        )

    # 8. 유효일 필터링
    vt_thr, req_count = 3.6, 400*len(volt_cols)
    vc = merged.groupby("date")[volt_cols].apply(lambda df: (df>=vt_thr).sum().sum())
    keep = vc[vc>=req_count].index
    merged = merged[merged["date"].isin(keep)].reset_index(drop=True)

    # 9. 가장 앞/뒤 하루 제거
    dates = merged["date"].unique()
    if len(dates) <= 2:
        print(f"{base_filename} - bank {bank_label}: 유효일 부족")
        return
    merged = merged[~merged["date"].isin([dates[0], dates[-1]])].reset_index(drop=True)
    unique_dates = merged["date"].unique()

    # 10. 채널별 2D 배열 생성 및 저장 (float32)
    for volt in volt_cols:
        X = np.empty([len(unique_dates), 1440], dtype=np.float32)
        valid_idx = []
        for i, d in enumerate(unique_dates):
            day = merged[merged["date"]==d]
            series = day[volt]
            if series.shape[0] != 1440:
                print(f"{base_filename}, bank{bank_label}, {d}, {volt}: {series.shape[0]} rows")
                continue
            valid_idx.append(i)
            X[i] = series.to_numpy(dtype=np.float32)
        if not valid_idx:
            print(f"{base_filename} - bank {bank_label}: {volt} 유효 데이터 없음")
            continue
        X = X[valid_idx]
        out_path = os.path.join(output_folder, f"{base_filename}_{volt}.npy")
        np.save(out_path, X)
        print(f"Saved: {out_path} shape={X.shape}")

# ────────────────────────────────────────────────────────────────
# 사용 예시
# ────────────────────────────────────────────────────────────────
if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 고정

    input_folder = 'preprocessing_A/00370960(0002)'
    ess_files = glob.glob(os.path.join(input_folder, '*.csv'))
    base = os.path.basename(input_folder)

    # ★ A_5%/<base>_1, A_5%/<base>_2 폴더 생성 ★
    bank1_out = os.path.join(ROOT_OUTPUT_DIR, f"{base}_1")
    bank2_out = os.path.join(ROOT_OUTPUT_DIR, f"{base}_2")
    for p in [bank1_out, bank2_out]:
        os.makedirs(p, exist_ok=True)

    for path in ess_files:
        df = pd.read_csv(path)
        name = os.path.splitext(os.path.basename(path))[0]
        df1 = df[df['bsc_fg_no']==1]
        df2 = df[df['bsc_fg_no']==2]
        if not df1.empty:
            process_bank_data_2d(df1, 1, name, bank1_out)
        if not df2.empty:
            process_bank_data_2d(df2, 2, name, bank2_out)
# Out:
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module1_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module1_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module5_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module5_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module9_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module9_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack17_module10_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module9_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module9_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module8_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module8_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack4_module2_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack4_module2_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module1_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module1_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack15_module17_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack15_module17_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module13_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module13_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module2_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module2_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack9_module17_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack9_module17_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module9_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module9_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack2_module17_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack2_module17_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module2_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module2_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module9_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module9_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module10_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module10_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module15_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module15_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module9_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module9_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack11_module4_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack11_module4_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack6_module10_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack6_module10_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack16_module4_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack16_module4_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack8_module17_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack8_module17_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack8_module17_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack8_module17_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack8_module17_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack8_module17_cell_volt_5.npy shape=(34, 1440)
# ...
# Saved: A_5%/00370960(0002)_1/rack1_module7_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack1_module7_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack1_module7_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack1_module7_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack1_module7_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack1_module7_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack1_module7_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack1_module7_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack1_module7_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack1_module7_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack1_module7_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module8_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module8_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack5_module15_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack5_module15_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack12_module8_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack12_module8_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module5_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module5_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack10_module12_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack10_module12_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack13_module1_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_2/rack13_module1_cell_volt_14.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_1.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_2.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_3.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_4.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_5.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_6.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_7.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_8.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_9.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_10.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_11.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_12.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_13.npy shape=(34, 1440)
# Saved: A_5%/00370960(0002)_1/rack7_module17_cell_volt_14.npy shape=(34, 1440)

# %% [markdown]
# # 2.A.R7M7C11

# %%
import os
import glob
import numpy as np
import pandas as pd

# ────────────────────────────────────────────────────────────────
# 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED = 42                # 고정 시드
MISSING_RATE = 0.15      # 결측치 비율 (5%)
ROOT_OUTPUT_DIR = 'A_5%'  # 최상위 저장 폴더

# 입력 폴더 및 CSV 파일 리스트
ess_name = 'preprocessing_A/2.A.R7M17C6'
ess_folder = os.path.basename(ess_name.rstrip('/'))
ess_list = glob.glob(os.path.join(ess_name, '*.csv'))

# ★ 출력 루트 폴더 생성: A_5%/<ess_folder> ★
output_root = os.path.join(ROOT_OUTPUT_DIR, ess_folder)
os.makedirs(output_root, exist_ok=True)

for ess_path in ess_list:
    # CSV 파일 읽기
    df = pd.read_csv(ess_path)
    
    # colec_dt 컬럼 처리: 없으면 clct_dt -> colec_dt
    if 'colec_dt' not in df.columns:
        if 'clct_dt' in df.columns:
            df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
        else:
            continue

    # cell_volt 컬럼명 정규화
    if not any(col.startswith('cell_volt_') for col in df.columns):
        rename_dict = {}
        for col in df.columns:
            if col.startswith('cel_volt_'):
                num_str = col.replace('cel_volt_', '')
                if num_str.isdigit():
                    rename_dict[col] = f'cell_volt_{int(num_str)}'
        if rename_dict:
            df.rename(columns=rename_dict, inplace=True)
    
    # datetime 변환 및 중복 제거
    df['colec_dt'] = pd.to_datetime(df['colec_dt'])
    df = df.drop_duplicates(subset='colec_dt', keep='first')
    
    # 분 단위 타임라인 생성 후 merge
    start_time = df['colec_dt'].min()
    end_time   = df['colec_dt'].max()
    time_idx   = pd.DataFrame({'colec_dt': pd.date_range(start_time, end_time, freq='min')})
    merged_df  = pd.merge(time_idx, df, on='colec_dt', how='left')
    
    # 불필요 컬럼 제거
    if 'Unnamed: 0' in merged_df.columns:
        merged_df.drop(columns=['Unnamed: 0'], inplace=True)
    
    # 전압 값 필터링 (3.3V 미만 -> NaN)
    cel_volt_cols = [c for c in merged_df.columns if c.startswith('cell_volt_')]
    merged_df.loc[merged_df['cell_volt_1'] < 3.3, cel_volt_cols] = np.nan
    
    # 날짜별 NaN 개수로 과도일 제거
    merged_df['date'] = merged_df['colec_dt'].dt.date
    nan_threshold = 1400
    nan_counts = merged_df.groupby('date')['cell_volt_1'].apply(lambda x: x.isna().sum())
    drop_dates = nan_counts[nan_counts > nan_threshold].index
    merged_nan_remove_df = merged_df[~merged_df['date'].isin(drop_dates)].reset_index(drop=True)
    
    # ★ 결측치 5% 무작위 주입 ★
    rng = np.random.default_rng(SEED)
    mask = rng.random(merged_nan_remove_df[cel_volt_cols].shape) < MISSING_RATE
    merged_nan_remove_df.loc[:, cel_volt_cols] = merged_nan_remove_df[cel_volt_cols].mask(mask)
    
    # # ★ 선형 보간 ★
    # merged_nan_remove_df[cel_volt_cols] = merged_nan_remove_df[cel_volt_cols].interpolate(method='polynomial', order=3)
    
    
    # ★ KNN 보간 ★
    imputer = KNNImputer(
        n_neighbors=5,
        weights='uniform',
        metric='nan_euclidean'
    )
    for day, idx in merged_nan_remove_df.groupby('date').groups.items():
        # 해당 날짜 그룹에서 적어도 하나의 관측값이 있는 컬럼만 선택
        cols = [c for c in cel_volt_cols if merged_nan_remove_df.loc[idx, c].notna().any()]
        if not cols:
            continue

        sub = merged_nan_remove_df.loc[idx, cols]
        imputed = imputer.fit_transform(sub)
        merged_nan_remove_df.loc[idx, cols] = pd.DataFrame(
            imputed,
            columns=cols,
            index=idx
        )

    # 전압 기준 유효 데이터 필터링
    voltage_threshold = 3.6
    required_valid_count = 400 * len(cel_volt_cols)
    valid_counts = merged_nan_remove_df.groupby('date')[cel_volt_cols] \
                            .apply(lambda x: (x >= voltage_threshold).sum().sum())
    keep_dates = valid_counts[valid_counts >= required_valid_count].index
    merged_valid_volt_df = merged_nan_remove_df[merged_nan_remove_df['date'].isin(keep_dates)] \
                                        .reset_index(drop=True)
    
    # 첫/마지막 날짜 제외
    if merged_valid_volt_df.empty:
        continue
    first_date = merged_valid_volt_df['date'].iloc[0]
    df_mid = merged_valid_volt_df[merged_valid_volt_df['date'] != first_date].reset_index(drop=True)
    last_date = df_mid['date'].iloc[-1]
    final_df = df_mid[df_mid['date'] != last_date].reset_index(drop=True)
    
    unique_dates = final_df['date'].unique()
    base_filename = os.path.splitext(os.path.basename(ess_path))[0]
    
    # 채널별 2D 배열 생성 및 저장 (float32)
    for volt in cel_volt_cols:
        X_array = np.empty([len(unique_dates), 1440], dtype=np.float32)
        for i, d in enumerate(unique_dates):
            series = final_df[final_df['date'] == d][volt]
            X_array[i] = series.to_numpy(dtype=np.float32)
        save_path = os.path.join(output_root, f"{base_filename}_{volt}.npy")
        np.save(save_path, X_array)

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.20        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

# KNN 보간
imputer = KNNImputer(n_neighbors=5,
                    weights='uniform',
                    metric='nan_euclidean')

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/3.A.R5M7C11'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_20%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order = 3)

        # 날짜별로 그룹 나누어 fit_transform
        for day, idx in clean_df.groupby('date').groups.items():
            sub = clean_df.loc[idx, cel_cols]               # 해당 날짜(그룹)의 1,440행
            imputed = imputer.fit_transform(sub)            # 하루치만 거리 계산
            clean_df.loc[idx, cel_cols] = pd.DataFrame(      # 원위치에 덮어쓰기
                imputed,
                columns=cel_cols,
                index=idx
            )


        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.20        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

imputer = KNNImputer(n_neighbors=5,
                    weights='uniform',
                    metric='nan_euclidean')

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/1.A.M5C10'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_20%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order=3)

        # 날짜별로 그룹 나누어 fit_transform
        for day, idx in clean_df.groupby('date').groups.items():
            sub = clean_df.loc[idx, cel_cols]               # 해당 날짜(그룹)의 1,440행
            imputed = imputer.fit_transform(sub)            # 하루치만 거리 계산
            clean_df.loc[idx, cel_cols] = pd.DataFrame(      # 원위치에 덮어쓰기
                imputed,
                columns=cel_cols,
                index=idx
            )

        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.20        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

imputer = KNNImputer(n_neighbors=5,
                    weights='uniform',
                    metric='nan_euclidean')

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/00321804(0002)'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_20%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order=3)

        # 날짜별로 그룹 나누어 fit_transform
        for day, idx in clean_df.groupby('date').groups.items():
            sub = clean_df.loc[idx, cel_cols]               # 해당 날짜(그룹)의 1,440행
            imputed = imputer.fit_transform(sub)            # 하루치만 거리 계산
            clean_df.loc[idx, cel_cols] = pd.DataFrame(      # 원위치에 덮어쓰기
                imputed,
                columns=cel_cols,
                index=idx
            )

        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.20        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

imputer = KNNImputer(n_neighbors=5,
                    weights='uniform',
                    metric='nan_euclidean')

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/00329601(0002)'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_20%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order=3)

        # 날짜별로 그룹 나누어 fit_transform
        for day, idx in clean_df.groupby('date').groups.items():
            sub = clean_df.loc[idx, cel_cols]               # 해당 날짜(그룹)의 1,440행
            imputed = imputer.fit_transform(sub)            # 하루치만 거리 계산
            clean_df.loc[idx, cel_cols] = pd.DataFrame(      # 원위치에 덮어쓰기
                imputed,
                columns=cel_cols,
                index=idx
            )

        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.20        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

imputer = KNNImputer(n_neighbors=5,
                    weights='uniform',
                    metric='nan_euclidean')

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/00391262(0002)'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_20%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order=3)

        # 날짜별로 그룹 나누어 fit_transform
        for day, idx in clean_df.groupby('date').groups.items():
            sub = clean_df.loc[idx, cel_cols]               # 해당 날짜(그룹)의 1,440행
            imputed = imputer.fit_transform(sub)            # 하루치만 거리 계산
            clean_df.loc[idx, cel_cols] = pd.DataFrame(      # 원위치에 덮어쓰기
                imputed,
                columns=cel_cols,
                index=idx
            )

        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)

# %%
"""
ESS CSV 전처리 스크립트 (결측치 5 % 주입 + 선형 보간 + float32 저장)
- random seed = 42 로 고정해 재현성 확보
- 결측치는 선형 보간 직전에 cel_volt_* 컬럼에 5 % 무작위 주입
- 선형 보간(`method="linear"`)으로 결측치 채우기
- 결과 `.npy` 는 float32 타입으로 저장
- 저장 경로 구조
  A_5%/
    └─ <원본 ESS 폴더명>/
        └─ <basefilename>_cell_volt_<n>.npy

베이스 코드(사용자 제공)에서 요구사항만 반영하여 전체 재작성
"""

import os
import glob
import numpy as np
import pandas as pd
from typing import List

# ────────────────────────────────────────────────────────────────
# 0. 설정 파라미터
# ────────────────────────────────────────────────────────────────
SEED: int            = 42          # 고정 시드
MISSING_RATE: float  = 0.20        # 5 % 결측치 비율
VOLT_DROP_THR: float = 3.3         # 3.3 V 미만 → NaN
NAN_DAY_THR: int     = 1400        # 하루 NaN 허용 개수 상한
VALID_VOLT_THR: float = 3.6        # 3.6 V 이상 유효 전압 기준
VALID_COUNT_REQ: int = 400         # 날짜별(분*채널) 유효 샘플 수

imputer = KNNImputer(n_neighbors=5,
                    weights='uniform',
                    metric='nan_euclidean')

# 입력 ESS 폴더 (예시)
ESS_SRC_DIR = 'preprocessing_A/00451902(0002)'

# 출력 루트 폴더 (결측 5 %)
ROOT_OUTPUT_DIR = 'A_20%'


def inject_random_missing(df: pd.DataFrame,
                           cols: List[str],
                           rate: float,
                           seed: int = 42) -> pd.DataFrame:

    rng = np.random.default_rng(seed)
    mask = rng.random(df[cols].shape) < rate
    df_missing = df.copy()
    df_missing.loc[:, cols] = df_missing[cols].mask(mask)
    return df_missing


def preprocess_ess_folder(ess_dir: str, root_out_dir: str):
    """단일 ESS 폴더(여러 CSV) 전처리 후 .npy 저장"""

    csv_list = glob.glob(os.path.join(ess_dir, '*.csv'))
    if not csv_list:
        print(f'[WARN] No CSV found in {ess_dir}')
        return

    # ▶ 출력 폴더 생성: A_5%/<ESS폴더명>
    ess_folder_name = os.path.basename(ess_dir.rstrip('/'))
    output_dir = os.path.join(root_out_dir, ess_folder_name)
    os.makedirs(output_dir, exist_ok=True)

    rng = np.random.default_rng(SEED)  # 폴더 단위 난수 생성기 (선택적)

    for csv_path in csv_list:
        df = pd.read_csv(csv_path)

        # 날짜 컬럼 통일
        if 'colec_dt' not in df.columns:
            if 'clct_dt' in df.columns:
                df.rename(columns={'clct_dt': 'colec_dt'}, inplace=True)
            else:
                print(f'[SKIP] {csv_path} : no date column')
                continue

        # cell_volt 컬럼명 정규화
        if not any(col.startswith('cell_volt_') for col in df.columns):
            rename_map = {}
            for col in df.columns:
                if col.startswith('cel_volt_'):
                    try:
                        num = int(col.replace('cel_volt_', ''))
                        rename_map[col] = f'cell_volt_{num}'
                    except ValueError:
                        continue
            if rename_map:
                df.rename(columns=rename_map, inplace=True)

        # ── 2‑2. 시계열 보완 & 기본 클린업 ────────────────────────
        df['colec_dt'] = pd.to_datetime(df['colec_dt'])
        start, end = df['colec_dt'].min(), df['colec_dt'].max()
        full_timeline = pd.DataFrame({'colec_dt': pd.date_range(start, end, freq='min')})
        merged = pd.merge(full_timeline, df, on='colec_dt', how='left')

        if 'Unnamed: 0' in merged.columns:
            merged.drop(columns='Unnamed: 0', inplace=True)

        cel_cols = [c for c in merged.columns if c.startswith('cell_volt_')]

        # 3. 전압 < 3.3V → NaN
        merged.loc[merged['cell_volt_1'] < VOLT_DROP_THR, cel_cols] = np.nan

        # 4. 하루 단위 NaN 과도일 제거
        merged['date'] = merged['colec_dt'].dt.date
        excessive_nan_dates = (
            merged.groupby('date')['cell_volt_1']
            .apply(lambda s: s.isna().sum())
            .loc[lambda s: s > NAN_DAY_THR]
            .index
        )
        clean_df = merged[~merged['date'].isin(excessive_nan_dates)].reset_index(drop=True)

        # ── 5. ★ 결측치 생성 (cel_cols 대상) ★ ───────────────
        clean_df = inject_random_missing(clean_df, cel_cols, MISSING_RATE, SEED)

        # # 6. 선형 보간
        # clean_df[cel_cols] = clean_df[cel_cols].interpolate(method='polynomial', order=3)

        # 날짜별로 그룹 나누어 fit_transform
        for day, idx in clean_df.groupby('date').groups.items():
            sub = clean_df.loc[idx, cel_cols]               # 해당 날짜(그룹)의 1,440행
            imputed = imputer.fit_transform(sub)            # 하루치만 거리 계산
            clean_df.loc[idx, cel_cols] = pd.DataFrame(      # 원위치에 덮어쓰기
                imputed,
                columns=cel_cols,
                index=idx
            )

        # 7. 전압 기준 유효 날짜 필터
        valid_counts = (
            clean_df.groupby('date')[cel_cols]
            .apply(lambda x: (x >= VALID_VOLT_THR).sum().sum())
        )
        keep_dates = valid_counts.loc[lambda s: s >= VALID_COUNT_REQ * len(cel_cols)].index
        valid_df = clean_df[clean_df['date'].isin(keep_dates)].reset_index(drop=True)

        # 8. 첫날/마지막날 제거
        if valid_df.empty:
            print(f'[WARN] {csv_path} : no valid dates left')
            continue
        first_date, last_date = valid_df['date'].iloc[0], valid_df['date'].iloc[-1]
        final_df = valid_df[(valid_df['date'] != first_date) & (valid_df['date'] != last_date)].reset_index(drop=True)
        if final_df.empty:
            print(f'[WARN] {csv_path} : nothing after dropping edge dates')
            continue

        # ── 9. 채널별 (날짜, 1440) float32 배열 저장 ────────────
        unique_dates = final_df['date'].unique()
        base_name = os.path.splitext(os.path.basename(csv_path))[0]

        for vcol in cel_cols:
            arr = np.empty((len(unique_dates), 1440), dtype=np.float32)
            for i, d in enumerate(unique_dates):
                arr[i] = final_df.loc[final_df['date'] == d, vcol].to_numpy(dtype=np.float32)

            np.save(os.path.join(output_dir, f'{base_name}_{vcol}.npy'), arr)

        print(f'[OK] {csv_path} → {output_dir}')


if __name__ == '__main__':
    np.random.seed(SEED)  # 전역 시드 (scikit‑learn 호환용)

    os.makedirs(ROOT_OUTPUT_DIR, exist_ok=True)
    preprocess_ess_folder(ESS_SRC_DIR, ROOT_OUTPUT_DIR)
